# %% [markdown]
# # Sheet 1

# %% [markdown]
# Set up the programm

# %%
from sklearn.datasets import load_digits
from sklearn import model_selection
import numpy as np
import matplotlib.pyplot as plt

digits = load_digits()
print(digits.keys())
data = digits["data"]
images = digits["images"]
target = digits["target"]
target_names = digits["target_names"]
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %% [markdown]
# **Exercise 1**
#
# Assign img and output the two images

# %%
img = np.array(images[3])

print(f"The size of the images is {img.shape}.")

assert 2 == len(img.shape)

plt.figure()
plt.gray()

plt.imshow(img, interpolation="nearest")
plt.show()

plt.imshow(img, interpolation="bicubic")
plt.show()
# Out:
# The size of the images is (8, 8).

# %% [markdown]
# Now filter and split the dataset

# %%
mask = [x for x in range(0, len(target)-1) if ((target[x] == 3) or (target[x] == 9))]

X_all = [data[x] for x in mask]
y_all = [target[x] for x in mask]

X_train, X_test, y_train, y_test = \
    model_selection.train_test_split(X_all, y_all,
                                     test_size=0.4, random_state=0)

# %% [markdown]
# **Exercise 2**
